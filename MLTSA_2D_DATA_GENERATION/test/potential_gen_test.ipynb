# %%
import sys
sys.path.append("../")
from src import spiral, zshape
import numpy as np
from matplotlib import pyplot as plt
from numpy import exp, sin, cos, tanh
from numpy import arctan2 as atan2
from TwoD_pot_data import *

# %%
from numpy import pi
# import matplotlib.pyplot as plt

N = 400
theta = np.sqrt(np.random.rand(N))*2*pi # np.linspace(0,2*pi,100)

r_a = 2*theta + pi
data_a = np.array([np.cos(theta)*r_a, np.sin(theta)*r_a]).T
x_a = data_a + np.random.randn(N,2)

r_b = -2*theta - pi
data_b = np.array([np.cos(theta)*r_b, np.sin(theta)*r_b]).T
x_b = data_b + np.random.randn(N,2)

res_a = np.append(x_a, np.zeros((N,1)), axis=1)
res_b = np.append(x_b, np.ones((N,1)), axis=1)

res = np.append(res_a, res_b, axis=0)
np.random.shuffle(res)
plt.scatter(res.T[0], res.T[1], c=res.T[2])
plt.title("Example of simple 2-spiral dataset")
# Out:
# Text(0.5, 1.0, 'Example of simple 2-spiral dataset')

# %%
TEST1_spiral = spiral.potential_spiral(2)
TEST1_spiral.visualize_3d()
plt.title("Two-Branch Spiral Potential Surface")
# Out:
# Text(0.5, 0.92, 'Two-Branch Spiral Potential Surface')

# %%
TEST2_spiral = spiral.potential_spiral(3)
pot, dx, dy = TEST2_spiral.generate_function()
print(pot)
# Out:
# Return in order of: potential, dx, dy
# -(0.05*x_symb**2 + 0.05*y_symb**2 + 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.03*x_symb**2 + 0.03*y_symb**2 + 3*atan2(x_symb, y_symb)) + 1)**2)

# %%
def spiral_potential_3b(x, y):
    return -(0.05*x**2 + 0.05*y**2 + 1)*np.exp(-1.02040816326531/(0.05*(x**2 + y**2)*np.sin(0.03*x**2 + 0.03*y**2 + 3*np.arctan2(x, y)) + 1)**2)
# Meshgrid of potential surface
[x,y] = np.meshgrid(np.linspace(-20, 20, 200),np.linspace(-20, 20, 200))

# Calculatin Energy for each
z = spiral_potential_3b(x, y)

#Plotting the potential Surface
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.viridis, alpha=0.6)
plt.title("Three-Branch Spiral Potential Surface")
# Out:
# Text(0.5, 0.92, 'Three-Branch Spiral Potential Surface')

# %%
TEST3_zshape = zshape.potential_zshape()
pot_z, dx_z, dy_z = TEST3_zshape.generate_function()
print(pot_z)
# Out:
# Return in order of: potential, dx, dy
# exp(-x_symb - 2) + exp(x_symb - 2) + exp(-y_symb - 1) + exp(y_symb - 3) - 5.41343343849984*exp(x_symb*(-2.83446712018141*x_symb - 2.26757369614512*y_symb + 2.26757369614512) + (y_symb - 1.0)*(-2.26757369614512*x_symb - 2.83446712018141*y_symb + 2.83446712018141)) - 11.3704845452139*exp(y_symb*(3.50140056022409*x_symb - 12.5050020008003*y_symb + 1.75070028011204) + (x_symb + 0.5)*(-2.00080032012805*x_symb + 3.50140056022409*y_symb - 1.00040016006403)) - 3.97887357729738*exp((1.875 - 1.25*x_symb)*(x_symb - 1.5) + (3.125 - 1.25*y_symb)*(y_symb - 2.5)) - 3.97887357729738*exp((-1.25*x_symb - 1.875)*(x_symb + 1.5) + (-1.25*y_symb - 0.625)*(y_symb + 0.5)) - 11.3704845452139*exp((x_symb - 0.5)*(-2.00080032012805*x_symb + 3.50140056022409*y_symb - 6.00240096038415) + (y_symb - 2.0)*(3.50140056022409*x_symb - 12.5050020008003*y_symb + 23.2593037214886))

# %%
get_pot_func(TEST3_zshape)
# Out:
# Return in order of: potential, dx, dy
# For best usage of the expressions, please use the following import command before running any of the functions:
#
# from numpy import exp, sin, cos
# from numpy import arctan2 as atan2
#
# def potential(x_symb, y_symb):
# ...

# %%
def potential_zshape(x_symb, y_symb):
    return exp(-x_symb - 2) + exp(x_symb - 2) + exp(-y_symb - 1) + exp(y_symb - 3) - 0.174819504261645*exp(-1.25*x_symb**2 - 3.75*x_symb - 1.25*y_symb**2 - 1.25*y_symb) - 9.66899354041083e-5*exp(-1.25*x_symb**2 + 3.75*x_symb - 1.25*y_symb**2 + 6.25*y_symb) - 0.31803826223279*exp(-2.83446712018141*x_symb**2 - 4.53514739229025*x_symb*y_symb + 4.53514739229025*x_symb - 2.83446712018141*y_symb**2 + 5.66893424036281*y_symb) - 1.43353817136578e-18*exp(-2.00080032012805*x_symb**2 + 7.00280112044818*x_symb*y_symb - 12.0048019207683*x_symb - 12.5050020008003*y_symb**2 + 46.5186074429772*y_symb) - 6.89516776904996*exp(-2.00080032012805*x_symb**2 + 7.00280112044818*x_symb*y_symb - 2.00080032012806*x_symb - 12.5050020008003*y_symb**2 + 3.50140056022409*y_symb)
# Meshgrid of potential surface
[x,y] = np.meshgrid(np.linspace(-2, 2, 200),np.linspace(-1, 3, 200))

# Calculatin Energy for each
z = potential_zshape(x, y)

#Plotting the potential Surface
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.viridis, alpha=0.6)
plt.title("Zshape Potential Surface")
# Out:
# Text(0.5, 0.92, 'Zshape Potential Surface')

# %%
TEST4_zshape = zshape.potential_zshape()
TEST4_zshape.visualize_3d()

# %%
TEST5_spiral = pot_generator('spiral')
# Out:
# Please check the attributes of generated objects, change any of the parameters before you use them

# %%
show_pot_attributes(TEST5_spiral)
# Out:
# {'BOUNDARY': 20,
#  'x_min': -20,
#  'x_max': 20,
#  'y_min': -20,
#  'y_max': 20,
#  'sigma': 0.35,
#  'warping_coeff': 0.01,
#  'decrease_coeff': 0.05,
#  'sinus_to_distance_coeff': 0.1,
#  'n_petals': 2}

# %%
get_pot_func(TEST5_spiral)
# Out:
# Return in order of: potential, dx, dy
# For best usage of the expressions, please use the following import command before running any of the functions:
#
# from numpy import exp, sin, cos
# from numpy import arctan2 as atan2
#
# def potential(x_symb, y_symb):
#     return -(0.05*x_symb**2 + 0.05*y_symb**2 + 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.02*x_symb**2 + 0.02*y_symb**2 + 2*atan2(x_symb, y_symb)) + 1)**2)
#
#
#
# def dx(x_symb, y_symb):
# ...

# %%
TEST5_spiral.n_petals = 3

# %%
show_pot_attributes(TEST5_spiral)
# Out:
# {'BOUNDARY': 20,
#  'x_min': -20,
#  'x_max': 20,
#  'y_min': -20,
#  'y_max': 20,
#  'sigma': 0.35,
#  'warping_coeff': 0.01,
#  'decrease_coeff': 0.05,
#  'sinus_to_distance_coeff': 0.1,
#  'n_petals': 3}

# %%
get_pot_func(TEST5_spiral)
# Out:
# Return in order of: potential, dx, dy
# For best usage of the expressions, please use the following import command before running any of the functions:
#
# from numpy import exp, sin, cos
# from numpy import arctan2 as atan2
#
# def potential(x_symb, y_symb):
#     return -(0.05*x_symb**2 + 0.05*y_symb**2 + 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.03*x_symb**2 + 0.03*y_symb**2 + 3*atan2(x_symb, y_symb)) + 1)**2)
#
#
#
# def dx(x_symb, y_symb):
# ...

# %%
from numpy import exp, sin, cos
from numpy import arctan2 as atan2

def potential(x_symb, y_symb):
    return -(0.05*x_symb**2 + 0.05*y_symb**2 + 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**2)



def dx(x_symb, y_symb):
    return -0.1*x_symb*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**2) - 1.02040816326531*(-0.2*x_symb*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) - 2*(0.16*x_symb + 8*y_symb/(x_symb**2 + y_symb**2))*(0.05*x_symb**2 + 0.05*y_symb**2)*cos(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)))*(-0.05*x_symb**2 - 0.05*y_symb**2 - 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**2)/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**3



def dy(x_symb, y_symb):
    return -0.1*y_symb*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**2) - 1.02040816326531*(-0.2*y_symb*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) - 2*(0.05*x_symb**2 + 0.05*y_symb**2)*(-8*x_symb/(x_symb**2 + y_symb**2) + 0.16*y_symb)*cos(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)))*(-0.05*x_symb**2 - 0.05*y_symb**2 - 1)*exp(-1.02040816326531/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**2)/(0.05*(x_symb**2 + y_symb**2)*sin(0.08*x_symb**2 + 0.08*y_symb**2 + 8*atan2(x_symb, y_symb)) + 1)**3

# %%
def spiral_potential_3b(x, y):
    return -(0.05*x**2 + 0.05*y**2 + 1)*np.exp(-1.02040816326531/(0.05*(x**2 + y**2)*np.sin(0.03*x**2 + 0.03*y**2 + 3*np.arctan2(x, y)) + 1)**2)
# Meshgrid of potential surface
[x,y] = np.meshgrid(np.linspace(-20, 20, 200),np.linspace(-20, 20, 200))

# Calculatin Energy for each
z = potential(x, y)

#Plotting the potential Surface
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.viridis, alpha=0.6)

# %%
# ?show_pot_attributes
# Out:
# Signature: show_pot_attributes(obj)
# Docstring:
# show_pot_attributes show the attributes of generated object, user could change those attributes before generation
#
# :param obj: obeject of potential class, yield by generate_potential_func above
# :type obj: object
# :return: attributes dictionary of self defined potential class, user could use attributes to assign value, however
#     this is not protected by type checking, so user should change the attributes very carefully and, only when they
#     are sure that the new input should work for potential generation.
# :rtype: dict
# File:      ~/MLTSA/MLTSA_2D_DATA_GENERATION/TwoD_pot_data.py
# Type:      function
